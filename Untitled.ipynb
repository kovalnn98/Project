# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import datasets, models

import numpy as np
import sys

# %%
path_mnist = "data\mnist.npz"

# %%
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in connect(self)
#    1413
# -> 1414             super().connect()
#    1415
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in connect(self)
#     937         self.sock = self._create_connection(
# --> 938             (self.host,self.port), self.timeout, self.source_address)
#     939         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# D:\Programms\envs\tf-gpu\lib\socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# D:\Programms\envs\tf-gpu\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     751     addrlist = []
# --> 752     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     753         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# D:\Programms\envs\tf-gpu\lib\site-packages\tensorflow_core\python\keras\utils\data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     263       try:
# --> 264         urlretrieve(origin, fpath, dl_progress)
#     265       except HTTPError as e:
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in https_open(self, req)
#    1361             return self.do_open(http.client.HTTPSConnection, req,
# -> 1362                 context=self._context, check_hostname=self._check_hostname)
#    1363
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1320             except OSError as err: # timeout error
# -> 1321                 raise URLError(err)
#    1322             r = h.getresponse()
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-30-8e718938d563> in <module>
#       1 mnist = tf.keras.datasets.mnist
# ----> 2 mnist.load_data(path_mnist)
#
# D:\Programms\envs\tf-gpu\lib\site-packages\tensorflow_core\python\keras\datasets\mnist.py in load_data(path)
#      48       origin=origin_folder + 'mnist.npz',
#      49       file_hash=
# ---> 50       '731c5ac602752760c8e48fbffcf8c3b850d9dc2a2aedcf2cc48468fc17b673d1')
#      51   with np.load(path, allow_pickle=True) as f:
#      52     x_train, y_train = f['x_train'], f['y_train']
#
# D:\Programms\envs\tf-gpu\lib\site-packages\tensorflow_core\python\keras\utils\data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     266         raise Exception(error_msg.format(origin, e.code, e.msg))
#     267       except URLError as e:
# --> 268         raise Exception(error_msg.format(origin, e.errno, e.reason))
#     269     except (Exception, KeyboardInterrupt) as e:
#     270       if os.path.exists(fpath):
#
# Exception: URL fetch failure on https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz: None -- [Errno 11001] getaddrinfo failed

# %%
import gzip
f = gzip.open('cifar-10-python.tar.gz', 'rb')
if sys.version_info < (3,):
    data = cPickle.load(f)
else:
    data = cPickle.load(f, encoding='bytes')
f.close()
(x_train, _), (x_test, _) = data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3c6ae9abd2f7> in <module>
#       4     data = cPickle.load(f)
#       5 else:
# ----> 6     data = cPickle.load(f, encoding='bytes')
#       7 f.close()
#       8 (x_train, _), (x_test, _) = data
#
# NameError: name 'cPickle' is not defined

# %%
path = 'cifar-10-python.tar.gz'
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data(path)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in connect(self)
#    1413
# -> 1414             super().connect()
#    1415
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in connect(self)
#     937         self.sock = self._create_connection(
# --> 938             (self.host,self.port), self.timeout, self.source_address)
#     939         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# D:\Programms\envs\tf-gpu\lib\socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# D:\Programms\envs\tf-gpu\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     751     addrlist = []
# --> 752     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     753         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# D:\Programms\envs\tf-gpu\lib\site-packages\tensorflow_core\python\keras\utils\data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     263       try:
# --> 264         urlretrieve(origin, fpath, dl_progress)
#     265       except HTTPError as e:
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in https_open(self, req)
#    1361             return self.do_open(http.client.HTTPSConnection, req,
# -> 1362                 context=self._context, check_hostname=self._check_hostname)
#    1363
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1320             except OSError as err: # timeout error
# -> 1321                 raise URLError(err)
#    1322             r = h.getresponse()
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-20-2e98a747e011> in <module>
#       1 path = 'cifar-10-python.tar.gz'
# ----> 2 (train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data(path)
#
# D:\Programms\envs\tf-gpu\lib\site-packages\tensorflow_core\python\keras\datasets\mnist.py in load_data(path)
#      48       origin=origin_folder + 'mnist.npz',
#      49       file_hash=
# ---> 50       '731c5ac602752760c8e48fbffcf8c3b850d9dc2a2aedcf2cc48468fc17b673d1')
#      51   with np.load(path, allow_pickle=True) as f:
#      52     x_train, y_train = f['x_train'], f['y_train']
#
# D:\Programms\envs\tf-gpu\lib\site-packages\tensorflow_core\python\keras\utils\data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     266         raise Exception(error_msg.format(origin, e.code, e.msg))
#     267       except URLError as e:
# --> 268         raise Exception(error_msg.format(origin, e.errno, e.reason))
#     269     except (Exception, KeyboardInterrupt) as e:
#     270       if os.path.exists(fpath):
#
# Exception: URL fetch failure on https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz: None -- [Errno 11001] getaddrinfo failed

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  cifar-10-python.tar.gz,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# tf.keras.utils.get_file('/cifar-10-python.tar.gz', extract=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-043aef0dd61c> in <module>
# ----> 1 train_ds = tf.keras.preprocessing.image_dataset_from_directory(
#       2   cifar-10-python.tar.gz,
#       3   validation_split=0.2,
#       4   subset="training",
#       5   seed=123,
#
# AttributeError: module 'tensorflow_core.keras.preprocessing' has no attribute 'image_dataset_from_directory'

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in connect(self)
#    1413
# -> 1414             super().connect()
#    1415
#
# D:\Programms\envs\tf-gpu\lib\http\client.py in connect(self)
#     937         self.sock = self._create_connection(
# --> 938             (self.host,self.port), self.timeout, self.source_address)
#     939         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# D:\Programms\envs\tf-gpu\lib\socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# D:\Programms\envs\tf-gpu\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     751     addrlist = []
# --> 752     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     753         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# D:\Programms\envs\tf-gpu\lib\site-packages\tensorflow_core\python\keras\utils\data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     263       try:
# --> 264         urlretrieve(origin, fpath, dl_progress)
#     265       except HTTPError as e:
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in https_open(self, req)
#    1361             return self.do_open(http.client.HTTPSConnection, req,
# -> 1362                 context=self._context, check_hostname=self._check_hostname)
#    1363
#
# D:\Programms\envs\tf-gpu\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1320             except OSError as err: # timeout error
# -> 1321                 raise URLError(err)
#    1322             r = h.getresponse()
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-9-bfd6f1225386> in <module>
# ----> 1 (train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
#       2 train_images, test_images = train_images / 255.0, test_images / 255.0
#
# D:\Programms\envs\tf-gpu\lib\site-packages\tensorflow_core\python\keras\datasets\cifar10.py in load_data()
#      43       untar=True,
#      44       file_hash=
# ---> 45       '6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce')
#      46
#      47   num_train_samples = 50000
#
# D:\Programms\envs\tf-gpu\lib\site-packages\tensorflow_core\python\keras\utils\data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     266         raise Exception(error_msg.format(origin, e.code, e.msg))
#     267       except URLError as e:
# --> 268         raise Exception(error_msg.format(origin, e.errno, e.reason))
#     269     except (Exception, KeyboardInterrupt) as e:
#     270       if os.path.exists(fpath):
#
# Exception: URL fetch failure on https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz: None -- [Errno 11001] getaddrinfo failed
